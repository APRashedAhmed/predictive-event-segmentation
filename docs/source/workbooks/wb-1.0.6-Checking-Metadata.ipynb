# %% [markdown]
# # 4.0.6 Checking Metadata
#
# Continuing where the last notebook left off since it was getting long.

# %% [markdown]
# ## Summary of Processing
#
# - Remove coarse segmentations that have no videos
# - Remove coarse segmentations that have a length mismatach with videos
# - Outer join videos with remaining coarse segmentations
# - Remove fine segmentations that have no corresponding video
# - Remove fine segmentations that have a length mismatach with videos
# - Outer join between master and fine
# - Remove 64 dim fvs with no matching video
# - Remove 64 dim fvs with length mismatch greater than 4 frames (none have an exact match, 204 have >4 frame mismatch)
# - Outer join between master and fvs
# - Remove I3D fvs with no matching video
# - Remove I3D fvs with length mismatch greater than 4 frames (none have an exact match, 104 have >4 frame mismatch)
# - Outer join between master and fvs

# %% [markdown]
# ## Jupyter Extensions

# %% [markdown]
# Load [watermark](https://github.com/rasbt/watermark) to see the state of the machine and environment that's running the notebook. To make sense of the options, take a look at the [usage](https://github.com/rasbt/watermark#usage) section of the readme.

# %%
# Load `watermark` extension
# %load_ext watermark
# Display the status of the machine and packages. Add more as necessary.
# %watermark -v -n -m -g -b -t -p torch,torchvision,cv2,h5py,pandas,matplotlib,seaborn,jupyterlab,lab
# Out:
# Tue Feb 25 2020 20:13:59
#
# CPython 3.6.10
# IPython 7.12.0
#
# torch 1.2.0
# torchvision 0.1.8
# cv2 3.4.2
# h5py 2.8.0
# pandas 1.0.1
# matplotlib 3.1.3
# seaborn 0.10.0
# jupyterlab 1.2.6
# lab 0+untagged.23.g7f125f8.dirty
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.4.0-173-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 16
# interpreter: 64bit
# Git hash   : 7f125f8034fb6eee72ac6d3e6a7a765d65007482
# Git branch : master

# %% [markdown]
# Load [autoreload](https://ipython.org/ipython-doc/3/config/extensions/autoreload.html) which will always reload modules marked with `%aimport`.
#
# This behavior can be inverted by running `autoreload 2` which will set everything to be auto-reloaded *except* for modules marked with `%aimport`.

# %%
# Load `autoreload` extension
# %load_ext autoreload
# Set autoreload behavior
# %autoreload 1

# %% [markdown]
# Load `matplotlib` in one of the more `jupyter`-friendly [rich-output modes](https://ipython.readthedocs.io/en/stable/interactive/plotting.html). Some options (that may or may not have worked) are `inline`, `notebook`, and `gtk`.

# %%
# Set the matplotlib mode
# %matplotlib inline

# %% [markdown]
# ## Set the GPU
#
# Make sure we aren't greedy.

# %%
# !nvidia-smi
# Out:
# Tue Feb 25 20:16:25 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.67       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN X (Pascal)    Off  | 00000000:04:00.0 Off |                  N/A |
# | 25%   45C    P2    55W / 250W |   1745MiB / 12196MiB |     10%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN X (Pascal)    Off  | 00000000:05:00.0 Off |                  N/A |
# | 30%   52C    P2    59W / 250W |   2885MiB / 12196MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   2  TITAN X (Pascal)    Off  | 00000000:08:00.0 Off |                  N/A |
# | 34%   58C    P2    60W / 250W |   2005MiB / 12196MiB |      8%      Default |
# +-------------------------------+----------------------+----------------------+
# |   3  TITAN X (Pascal)    Off  | 00000000:09:00.0 Off |                  N/A |
# | 56%   84C    P2   171W / 250W |  10485MiB / 12196MiB |     99%      Default |
# +-------------------------------+----------------------+----------------------+
# |   4  TITAN X (Pascal)    Off  | 00000000:84:00.0 Off |                  N/A |
# | 68%   85C    P2   207W / 250W |  10443MiB / 12196MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
# |   5  TITAN X (Pascal)    Off  | 00000000:85:00.0 Off |                  N/A |
# | 51%   85C    P2   197W / 250W |  10157MiB / 12196MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
# |   6  TITAN X (Pascal)    Off  | 00000000:88:00.0 Off |                  N/A |
# | 51%   83C    P2   238W / 250W |   9921MiB / 12196MiB |     99%      Default |
# +-------------------------------+----------------------+----------------------+
# |   7  TITAN X (Pascal)    Off  | 00000000:89:00.0 Off |                  N/A |
# | 31%   53C    P2    62W / 250W |   2306MiB / 12196MiB |      8%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0      6389      C   python                                      1735MiB |
# |    1     18085      C   python                                      2875MiB |
# |    2      8742      C   python                                      1995MiB |
# |    3     19363      C   python                                     10475MiB |
# |    4     30662      C   python                                     10433MiB |
# |    5     19363      C   python                                     10147MiB |
# |    6     30662      C   python                                      9911MiB |
# |    7     14368      C   python                                      1733MiB |
# |    7     29090      C   /home/mvaishn1/vreason/bin/python            563MiB |
# +-----------------------------------------------------------------------------+

# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %% [markdown]
# ## Imports

# %%
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# Local imports that may or may not be autoreloaded. This section contains things that will likely have to be re-imported multiple times, and have additions or subtractions made throughout the project.

# %%
# Constants to be used throughout the package
# %aimport lab.index
from lab.index import DIR_DATA_INT, DIR_DATA_RAW
# %aimport lab.breakfast.constants
from lab.breakfast.constants import SEED
# Import the data subdirectories
# %aimport lab.breakfast.index
from lab.breakfast.index import (DIR_BREAKFAST, 
                                 DIR_RAW_BREAKFAST,
                                 DIR_BREAKFAST_META,
                                 DIR_BREAKFAST_VIDEOS,
                                 DIR_BREAKFAST_DATA, 
                                 DIR_COARSE_SEG, 
                                 DIR_FINE_SEG,
                                 DIR_I3D_FVS,
                                )

# %% [markdown]
# ## Initial Setup

# %% [markdown]
# Set [seaborn defaults](https://seaborn.pydata.org/generated/seaborn.set.html) for matplotlib.

# %%
sns.set()

# %% [markdown]
# ## Loading the DFs

# %%
video_df = pd.read_csv(str(DIR_BREAKFAST_META / 'video_meta.csv'))
coarse_df = pd.read_csv(str(DIR_BREAKFAST_META / 'coarse_segmentations_meta.csv'))
fine_df = pd.read_csv(str(DIR_BREAKFAST_META / 'fine_segmentations_meta.csv'))
fvs_df = pd.read_csv(str(DIR_BREAKFAST_META / '64dim_fvs_meta.csv'))
i3d_df = pd.read_csv(str(DIR_BREAKFAST_META / 'i3d_fvs_meta.csv'))

# %%
all_dfs = {'videos' : video_df, 
           'coarse' : coarse_df, 
           'fine' : fine_df, 
           '64dim_fvs' : fvs_df, 
           'i3d_fvs' : i3d_df}

# %% [markdown]
# ## Videos vs Coarse

# %%
for name, val in all_dfs.items():
    print(name, len(val))
# Out:
# videos 1989
# coarse 1712
# fine 1285
# 64dim_fvs 1712
# i3d_fvs 1712

# %%
1989 - 1712
# Out:
# 277

# %% [markdown]
# ### Not Total Correspondance

# %%
dropped_videos_2_coarse = video_df[~video_df.id.isin(coarse_df.id)].dropna()
len(dropped_videos_2_coarse)
# Out:
# 309

# %%
dropped_videos_2_coarse.head()
# Out:
#                                                  path  length  patient  \
# 29  /media/data_cifs2/apra/work/labwork/data/exter...    1811       39
# 30  /media/data_cifs2/apra/work/labwork/data/exter...     947       39
# 33  /media/data_cifs2/apra/work/labwork/data/exter...     644       39
# 34  /media/data_cifs2/apra/work/labwork/data/exter...    4407       39
# 35  /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
#
#           action  camera  channel                        id
# 29         juice  stereo      0.0         39_juice_stereo_0
# 30          milk  stereo      0.0          39_milk_stereo_0
# 33        coffee  stereo      0.0        39_coffee_stereo_0
# 34  scrambledegg  stereo      0.0  39_scrambledegg_stereo_0
# 35      friedegg  stereo      0.0      39_friedegg_stereo_0

# %%
dropped_videos_2_coarse.camera.unique()
# Out:
# array(['stereo'], dtype=object)

# %%
len(np.unique(coarse_df.id))
# Out:
# 1712

# %%
len(pd.merge(video_df, coarse_df, how='inner', on='id'))
# Out:
# 1680

# %%
len(video_df)
# Out:
# 1989

# %% [markdown]
# ### 32 Segmentations Don't Have Videos

# %%
coarse_ids = coarse_df.id.to_list()
video_ids = video_df.id.to_list()

# %%
not_in_video_ids = [cid for cid in coarse_ids if cid not in video_ids]

# %%
len(not_in_video_ids)
# Out:
# 32

# %%
not_in_video_ids
# Out:
# ['22_cereals_stereo_1',
#  '49_cereals_stereo_1',
#  '17_cereals_stereo_1',
#  '13_cereals_stereo_1',
#  '14_cereals_stereo_1',
#  '20_cereals_stereo_1',
#  '15_salat_stereo_1',
#  '17_salat_stereo_1',
#  '34_salat_stereo_1',
#  '13_scrambledegg_stereo_1',
#  '14_scrambledegg_stereo_1',
#  '16_scrambledegg_stereo_1',
#  '15_scrambledegg_stereo_1',
#  '15_milk_stereo_1',
#  '13_milk_stereo_1',
#  '23_milk_stereo_1',
#  '15_sandwich_stereo_1',
#  '21_sandwich_stereo_1',
#  '7_sandwich_stereo_1',
#  '14_juice_stereo_1',
#  '15_juice_stereo_1',
#  '7_juice_stereo_1',
#  '16_coffee_stereo_1',
#  '26_coffee_stereo_1',
#  '14_coffee_stereo_1',
#  '21_friedegg_stereo_1',
#  '22_friedegg_stereo_1',
#  '23_friedegg_stereo_1',
#  '24_friedegg_stereo_1',
#  '16_pancake_stereo_1',
#  '15_pancake_stereo_1',
#  '4_pancake_stereo_1']

# %% [markdown]
# ### Remove Coarse Segmentations that have no videos

# %%
good_coarse_ids = [cid for cid in coarse_ids if cid not in not_in_video_ids]
len(good_coarse_ids)
# Out:
# 1680

# %%
coarse_df_cleaner = coarse_df[coarse_df.id.isin(good_coarse_ids)]
len(coarse_df_cleaner)
# Out:
# 1680

# %% [markdown]
# ### 309 Videos Have No Coarse Segments

# %%
doesnt_have_coarse_segments = [vid for vid in video_ids if vid not in coarse_ids]

# %%
len(doesnt_have_coarse_segments)
# Out:
# 309

# %% [markdown]
# ### Three Have Different Lengths

# %%
common_videos = video_df[video_df.id.isin(coarse_df_cleaner.id)]
merged_videos_coarse_common = common_videos[['id', 'length']].merge(
    coarse_df_cleaner[['id', 'length']],
    on='id')
merged_videos_coarse_common
# Out:
#                      id  length_x  length_y
# 0        39_salat_cam01      2669      2669
# 1          39_tea_cam01      1304      1304
# 2      39_pancake_cam01      8990      8990
# 3      39_cereals_cam01       699       699
# 4     39_friedegg_cam01      2890      2890
# ...                 ...       ...       ...
# 1675    5_cereals_cam01      1186      1186
# 1676      5_juice_cam01      2795      2795
# 1677     5_coffee_cam01      1123      1123
# 1678   5_juice_stereo_1      2795      2795
# 1679    5_milk_stereo_1      1084      1084
#
# [1680 rows x 3 columns]

# %%
video_lengths = merged_videos_coarse_common.length_x.values
coarse_lengths = merged_videos_coarse_common.length_y.values

# %%
video_lengths[:5]
# Out:
# array([2669, 1304, 8990,  699, 2890])

# %%
coarse_lengths[:5]
# Out:
# array([2669, 1304, 8990,  699, 2890])

# %%
sum(video_lengths != coarse_lengths)
# Out:
# 3

# %% [markdown]
# Three of them have different lengths.

# %%
merged_videos_coarse_common.iloc[np.where(video_lengths != coarse_lengths)]
# Out:
#                     id  length_x  length_y
# 173  8_coffee_webcam01       275       289
# 249  43_juice_stereo_1      1622      1635
# 264     43_juice_cam02      1635      1622

# %% [markdown]
# They do indeed have different lengths

# %% [markdown]
# ### Removing the Bad IDs

# %%
bad_ids = merged_videos_coarse_common.iloc[np.where(video_lengths != coarse_lengths)].id.to_list()
bad_ids
# Out:
# ['8_coffee_webcam01', '43_juice_stereo_1', '43_juice_cam02']

# %%
merged_videos_coarse_common[merged_videos_coarse_common.id.isin(bad_ids)]
# Out:
#                     id  length_x  length_y
# 173  8_coffee_webcam01       275       289
# 249  43_juice_stereo_1      1622      1635
# 264     43_juice_cam02      1635      1622

# %%
len(coarse_df_cleaner)
# Out:
# 1680

# %%
coarse_df_cleaner = coarse_df_cleaner[~coarse_df_cleaner.id.isin(bad_ids)]
coarse_df_cleaner
# Out:
#                                                    path  patient   action  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...       18  cereals
# 1     /media/data_cifs2/apra/work/labwork/data/exter...       54  cereals
# 2     /media/data_cifs2/apra/work/labwork/data/exter...       34  cereals
# 3     /media/data_cifs2/apra/work/labwork/data/exter...       13  cereals
# 4     /media/data_cifs2/apra/work/labwork/data/exter...       51  cereals
# ...                                                 ...      ...      ...
# 1707  /media/data_cifs2/apra/work/labwork/data/exter...       36  pancake
# 1708  /media/data_cifs2/apra/work/labwork/data/exter...       54  pancake
# 1709  /media/data_cifs2/apra/work/labwork/data/exter...       13  pancake
# 1710  /media/data_cifs2/apra/work/labwork/data/exter...       21  pancake
# 1711  /media/data_cifs2/apra/work/labwork/data/exter...       12  pancake
#
#         camera  channel                   id  length
# 0     webcam02      NaN  18_cereals_webcam02     465
# 1        cam01      NaN     54_cereals_cam01     747
# 2       stereo      1.0  34_cereals_stereo_1     765
# 3        cam01      NaN     13_cereals_cam01     679
# 4     webcam02      NaN  51_cereals_webcam02     711
# ...        ...      ...                  ...     ...
# 1707  webcam02      NaN  36_pancake_webcam02    7053
# 1708    stereo      1.0  54_pancake_stereo_1    3344
# 1709     cam01      NaN     13_pancake_cam01    4440
# 1710     cam01      NaN     21_pancake_cam01    5845
# 1711  webcam01      NaN  12_pancake_webcam01    2874
#
# [1677 rows x 7 columns]

# %% [markdown]
# ### Making the Master DF

# %%
master_df = video_df
master_df.head()
# Out:
#                                          path_videos  length  patient  \
# 0  /media/data_cifs2/apra/work/labwork/data/exter...    2669       39
# 1  /media/data_cifs2/apra/work/labwork/data/exter...    1304       39
# 2  /media/data_cifs2/apra/work/labwork/data/exter...    8990       39
# 3  /media/data_cifs2/apra/work/labwork/data/exter...     699       39
# 4  /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
#
#      action camera  channel                 id
# 0     salat  cam01      NaN     39_salat_cam01
# 1       tea  cam01      NaN       39_tea_cam01
# 2   pancake  cam01      NaN   39_pancake_cam01
# 3   cereals  cam01      NaN   39_cereals_cam01
# 4  friedegg  cam01      NaN  39_friedegg_cam01

# %%
master_df.rename(columns={'path' : 'path_videos'}, inplace=True)
master_df.head()
# Out:
#                                          path_videos  length  patient  \
# 0  /media/data_cifs2/apra/work/labwork/data/exter...    2669       39
# 1  /media/data_cifs2/apra/work/labwork/data/exter...    1304       39
# 2  /media/data_cifs2/apra/work/labwork/data/exter...    8990       39
# 3  /media/data_cifs2/apra/work/labwork/data/exter...     699       39
# 4  /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
#
#      action camera  channel                 id
# 0     salat  cam01      NaN     39_salat_cam01
# 1       tea  cam01      NaN       39_tea_cam01
# 2   pancake  cam01      NaN   39_pancake_cam01
# 3   cereals  cam01      NaN   39_cereals_cam01
# 4  friedegg  cam01      NaN  39_friedegg_cam01

# %%
master_df = master_df.merge(coarse_df_cleaner[['id', 'path']], how='outer', on='id')
master_df.rename(columns={'path' : 'path_coarse'}, inplace=True)
master_df
# Out:
#                                             path_videos  length  patient  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...    2669       39
# 1     /media/data_cifs2/apra/work/labwork/data/exter...    1304       39
# 2     /media/data_cifs2/apra/work/labwork/data/exter...    8990       39
# 3     /media/data_cifs2/apra/work/labwork/data/exter...     699       39
# 4     /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
# ...                                                 ...     ...      ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...    1123        5
# 1985  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1986  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
#
#         action  camera  channel                 id  \
# 0        salat   cam01      NaN     39_salat_cam01
# 1          tea   cam01      NaN       39_tea_cam01
# 2      pancake   cam01      NaN   39_pancake_cam01
# 3      cereals   cam01      NaN   39_cereals_cam01
# 4     friedegg   cam01      NaN  39_friedegg_cam01
# ...        ...     ...      ...                ...
# 1984    coffee   cam01      NaN     5_coffee_cam01
# 1985     juice  stereo      0.0   5_juice_stereo_0
# 1986      milk  stereo      0.0    5_milk_stereo_0
# 1987     juice  stereo      1.0   5_juice_stereo_1
# 1988      milk  stereo      1.0    5_milk_stereo_1
#
#                                             path_coarse
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
# [1989 rows x 8 columns]

# %% [markdown]
# ## Master vs Fine Segmentations

# %% [markdown]
# ### 499 IDs in Fine Aren't in Master

# %%
fine_ids = fine_df.id.to_list()
master_ids = master_df.id.to_list()

# %%
len(fine_ids)
# Out:
# 1285

# %%
fine_ids[:5]
# Out:
# ['5_cereals_stereo_1',
#  '18_cereals_webcam02',
#  '25_cereals_stereo_1',
#  '8_cereals_cam01',
#  '34_cereals_stereo_1']

# %%
not_in_master = [fid for fid in fine_ids if fid not in master_ids]
len(not_in_master)
# Out:
# 499

# %%
fine_df_cleaner = fine_df[~fine_df.id.isin(not_in_master)]
fine_df_cleaner
# Out:
#                                                    path  patient   action  \
# 1     /media/data_cifs2/apra/work/labwork/data/exter...       18  cereals
# 4     /media/data_cifs2/apra/work/labwork/data/exter...       34  cereals
# 6     /media/data_cifs2/apra/work/labwork/data/exter...       51  cereals
# 7     /media/data_cifs2/apra/work/labwork/data/exter...       16  cereals
# 8     /media/data_cifs2/apra/work/labwork/data/exter...       52  cereals
# ...                                                 ...      ...      ...
# 1274  /media/data_cifs2/apra/work/labwork/data/exter...       14  pancake
# 1278  /media/data_cifs2/apra/work/labwork/data/exter...        5  pancake
# 1280  /media/data_cifs2/apra/work/labwork/data/exter...       54  pancake
# 1281  /media/data_cifs2/apra/work/labwork/data/exter...       13  pancake
# 1283  /media/data_cifs2/apra/work/labwork/data/exter...       12  pancake
#
#         camera  channel                   id  length
# 1     webcam02      NaN  18_cereals_webcam02     465
# 4       stereo      1.0  34_cereals_stereo_1     765
# 6     webcam02      NaN  51_cereals_webcam02     711
# 7     webcam01      NaN  16_cereals_webcam01     548
# 8        cam02      NaN     52_cereals_cam02     805
# ...        ...      ...                  ...     ...
# 1274  webcam01      NaN  14_pancake_webcam01    5930
# 1278     cam01      NaN      5_pancake_cam01    5896
# 1280    stereo      1.0  54_pancake_stereo_1    3344
# 1281     cam01      NaN     13_pancake_cam01    4440
# 1283  webcam01      NaN  12_pancake_webcam01    2866
#
# [786 rows x 7 columns]

# %% [markdown]
# ### None have Different Lengths

# %%
common_videos = master_df[master_df.id.isin(fine_df_cleaner.id)]
merged_videos_fine_common = common_videos[['id', 'length']].merge(
    fine_df_cleaner[['id', 'length']],
    on='id')
merged_videos_fine_common
# Out:
#                        id  length_x  length_y
# 0       39_sandwich_cam01      1524      1524
# 1    39_sandwich_webcam01      1524      1524
# 2    39_sandwich_webcam02      1524      1524
# 3    39_sandwich_stereo_1      1524      1524
# 4       39_sandwich_cam02      1524      1524
# ..                    ...       ...       ...
# 616   15_cereals_stereo_1       383       383
# 617  5_scrambledegg_cam01      2700      2700
# 618       5_pancake_cam01      5896      5896
# 619           5_tea_cam01      1665      1665
# 620       5_milk_stereo_1      1084      1084
#
# [621 rows x 3 columns]

# %%
video_lengths = merged_videos_fine_common.length_x.values
fine_lengths = merged_videos_fine_common.length_y.values

# %%
sum(video_lengths != fine_lengths)
# Out:
# 0

# %% [markdown]
# ### Adding to the Master DF

# %%
fine_df_cleaner.rename(columns={'path' : 'path_fine'}, inplace=True)
fine_df_cleaner.head()
# Out:
# /media/data/conda/abdullah/envs/bk/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                            path_fine  patient   action  \
# 1  /media/data_cifs2/apra/work/labwork/data/exter...       18  cereals
# 4  /media/data_cifs2/apra/work/labwork/data/exter...       34  cereals
# 6  /media/data_cifs2/apra/work/labwork/data/exter...       51  cereals
# 7  /media/data_cifs2/apra/work/labwork/data/exter...       16  cereals
# 8  /media/data_cifs2/apra/work/labwork/data/exter...       52  cereals
#
#      camera  channel                   id  length
# 1  webcam02      NaN  18_cereals_webcam02     465
# 4    stereo      1.0  34_cereals_stereo_1     765
# 6  webcam02      NaN  51_cereals_webcam02     711
# 7  webcam01      NaN  16_cereals_webcam01     548
# 8     cam02      NaN     52_cereals_cam02     805

# %%
master_df = master_df.merge(fine_df_cleaner[['id', 'path_fine']], how='outer', on='id')
master_df
# Out:
#                                             path_videos  length  patient  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...    2669       39
# 1     /media/data_cifs2/apra/work/labwork/data/exter...    1304       39
# 2     /media/data_cifs2/apra/work/labwork/data/exter...    8990       39
# 3     /media/data_cifs2/apra/work/labwork/data/exter...     699       39
# 4     /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
# ...                                                 ...     ...      ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...    1123        5
# 1985  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1986  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
#
#         action  camera  channel                 id  \
# 0        salat   cam01      NaN     39_salat_cam01
# 1          tea   cam01      NaN       39_tea_cam01
# 2      pancake   cam01      NaN   39_pancake_cam01
# 3      cereals   cam01      NaN   39_cereals_cam01
# 4     friedegg   cam01      NaN  39_friedegg_cam01
# ...        ...     ...      ...                ...
# 1984    coffee   cam01      NaN     5_coffee_cam01
# 1985     juice  stereo      0.0   5_juice_stereo_0
# 1986      milk  stereo      0.0    5_milk_stereo_0
# 1987     juice  stereo      1.0   5_juice_stereo_1
# 1988      milk  stereo      1.0    5_milk_stereo_1
#
#                                             path_coarse  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
#                                               path_fine
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1984                                                NaN
# 1985                                                NaN
# 1986                                                NaN
# 1987                                                NaN
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
# [1989 rows x 9 columns]

# %% [markdown]
# ## Master vs 64 Dim FVs

# %% [markdown]
# ### 32 Not in Master

# %%
fvs_ids = fvs_df.id.to_list()
len(fvs_ids)
# Out:
# 1712

# %%
fvs_ids[:5]
# Out:
# ['18_cereals_webcam02',
#  '54_cereals_cam01',
#  '34_cereals_stereo_1',
#  '13_cereals_cam01',
#  '51_cereals_webcam02']

# %%
not_in_master = [fvid for fvid in fvs_ids if fvid not in master_ids]
len(not_in_master)
# Out:
# 32

# %%
fvs_df_cleaner = fvs_df[~fvs_df.id.isin(not_in_master)]
fvs_df_cleaner
# Out:
#                                                    path  patient   action  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...       18  cereals
# 1     /media/data_cifs2/apra/work/labwork/data/exter...       54  cereals
# 2     /media/data_cifs2/apra/work/labwork/data/exter...       34  cereals
# 3     /media/data_cifs2/apra/work/labwork/data/exter...       13  cereals
# 4     /media/data_cifs2/apra/work/labwork/data/exter...       51  cereals
# ...                                                 ...      ...      ...
# 1707  /media/data_cifs2/apra/work/labwork/data/exter...       36  pancake
# 1708  /media/data_cifs2/apra/work/labwork/data/exter...       54  pancake
# 1709  /media/data_cifs2/apra/work/labwork/data/exter...       13  pancake
# 1710  /media/data_cifs2/apra/work/labwork/data/exter...       21  pancake
# 1711  /media/data_cifs2/apra/work/labwork/data/exter...       12  pancake
#
#         camera  channel                   id  length
# 0     webcam02      NaN  18_cereals_webcam02     461
# 1        cam01      NaN     54_cereals_cam01     743
# 2       stereo      1.0  34_cereals_stereo_1     761
# 3        cam01      NaN     13_cereals_cam01     675
# 4     webcam02      NaN  51_cereals_webcam02     707
# ...        ...      ...                  ...     ...
# 1707  webcam02      NaN  36_pancake_webcam02    7049
# 1708    stereo      1.0  54_pancake_stereo_1    3340
# 1709     cam01      NaN     13_pancake_cam01    4436
# 1710     cam01      NaN     21_pancake_cam01    5841
# 1711  webcam01      NaN  12_pancake_webcam01    2870
#
# [1680 rows x 7 columns]

# %% [markdown]
# ### Every FV has Different Lengths

# %%
common_videos = master_df[master_df.id.isin(fvs_df_cleaner.id)]
merged_videos_fvs_common = common_videos[['id', 'length']].merge(
    fvs_df_cleaner[['id', 'length']],
    on='id')
merged_videos_fvs_common
# Out:
#                      id  length_x  length_y
# 0        39_salat_cam01      2669      2665
# 1          39_tea_cam01      1304      1300
# 2      39_pancake_cam01      8990      8986
# 3      39_cereals_cam01       699       695
# 4     39_friedegg_cam01      2890      2886
# ...                 ...       ...       ...
# 1675    5_cereals_cam01      1186      1182
# 1676      5_juice_cam01      2795      2791
# 1677     5_coffee_cam01      1123      1119
# 1678   5_juice_stereo_1      2795      2791
# 1679    5_milk_stereo_1      1084      1080
#
# [1680 rows x 3 columns]

# %%
video_lengths = merged_videos_fvs_common.length_x.values
fv_lengths = merged_videos_fvs_common.length_y.values

# %%
sum(video_lengths != fv_lengths)
# Out:
# 1680

# %% [markdown]
# ### Majority Are Exactly 4 Frames Less

# %%
sum(video_lengths == fv_lengths + 4)
# Out:
# 1476

# %% [markdown]
# ### 204 Differ By More than 4 Frames

# %%
sum(video_lengths != fv_lengths + 4)
# Out:
# 204

# %% [markdown]
# ### Removing the Bad IDs

# %%
bad_ids = merged_videos_fvs_common.iloc[np.where(video_lengths != fv_lengths+4)].id.to_list()
bad_ids
# Out:
# ['39_salat_webcam02',
#  '39_tea_webcam02',
#  '39_pancake_stereo_1',
#  '39_juice_stereo_1',
#  '39_tea_stereo_1',
#  '39_tea_cam02',
#  '41_coffee_cam01',
#  '41_juice_cam01',
#  '41_scrambledegg_webcam01',
#  '41_coffee_webcam01',
#  '41_cereals_webcam01',
#  '41_pancake_stereo_1',
#  '41_juice_stereo_1',
#  '41_sandwich_stereo_1',
#  '41_juice_cam02',
#  '50_tea_webcam01',
#  '50_cereals_webcam01',
#  '50_tea_webcam02',
#  '50_juice_stereo_1',
#  '50_sandwich_cam02',
#  '50_tea_cam02',
#  '4_scrambledegg_cam01',
#  '4_milk_cam01',
#  '4_tea_webcam01',
#  '4_milk_webcam01',
#  '4_friedegg_webcam01',
#  '4_cereals_webcam01',
#  '4_milk_webcam02',
#  '4_scrambledegg_stereo_1',
#  '4_sandwich_stereo_1',
#  '8_juice_cam01',
#  '8_juice_webcam01',
#  '8_cereals_webcam01',
#  '53_friedegg_webcam01',
#  '53_milk_webcam01',
#  '53_milk_webcam02',
#  '53_salat_stereo_1',
#  '53_coffee_cam02',
#  '53_scrambledegg_cam02',
#  '53_pancake_cam02',
#  '53_milk_cam02',
#  '43_scrambledegg_cam01',
#  '43_juice_webcam01',
#  '43_milk_stereo_1',
#  '43_juice_stereo_1',
#  '43_pancake_stereo_1',
#  '43_scrambledegg_stereo_1',
#  '24_juice_cam01',
#  '24_pancake_webcam02',
#  '24_friedegg_webcam02',
#  '24_milk_cam02',
#  '47_coffee_cam01',
#  '47_tea_webcam01',
#  '47_friedegg_webcam01',
#  '47_friedegg_cam02',
#  '26_juice_cam01',
#  '26_salat_cam01',
#  '26_cereals_cam01',
#  '26_coffee_webcam02',
#  '26_cereals_webcam02',
#  '3_milk_cam01',
#  '3_sandwich_webcam01',
#  '3_cereals_webcam02',
#  '19_cereals_cam01',
#  '19_coffee_cam01',
#  '19_sandwich_cam01',
#  '19_cereals_webcam01',
#  '25_cereals_cam01',
#  '25_friedegg_cam01',
#  '25_coffee_cam01',
#  '25_cereals_webcam02',
#  '25_friedegg_webcam02',
#  '20_juice_webcam02',
#  '20_juice_stereo_1',
#  '13_cereals_webcam01',
#  '13_sandwich_webcam01',
#  '54_pancake_cam01',
#  '54_juice_cam01',
#  '54_salat_cam01',
#  '54_scrambledegg_webcam01',
#  '54_tea_webcam01',
#  '54_juice_stereo_1',
#  '30_juice_cam01',
#  '30_juice_cam02',
#  '30_milk_cam02',
#  '32_milk_cam01',
#  '32_tea_cam01',
#  '32_friedegg_cam01',
#  '32_milk_stereo_1',
#  '32_milk_cam02',
#  '32_sandwich_cam02',
#  '32_juice_cam02',
#  '32_friedegg_cam02',
#  '49_cereals_cam01',
#  '49_coffee_cam01',
#  '49_milk_webcam01',
#  '49_juice_cam02',
#  '52_pancake_webcam01',
#  '52_cereals_webcam01',
#  '52_sandwich_stereo_1',
#  '21_sandwich_cam01',
#  '21_friedegg_webcam02',
#  '21_coffee_stereo_1',
#  '21_cereals_cam02',
#  '45_friedegg_cam02',
#  '18_pancake_cam01',
#  '18_sandwich_webcam01',
#  '18_milk_webcam01',
#  '18_salat_webcam02',
#  '18_cereals_stereo_1',
#  '18_milk_stereo_1',
#  '44_sandwich_cam01',
#  '44_cereals_webcam02',
#  '44_salat_cam02',
#  '29_pancake_stereo_1',
#  '14_milk_webcam01',
#  '46_scrambledegg_cam01',
#  '46_scrambledegg_webcam01',
#  '46_friedegg_webcam02',
#  '46_scrambledegg_cam02',
#  '17_juice_cam01',
#  '17_cereals_cam01',
#  '17_tea_cam01',
#  '17_tea_webcam01',
#  '17_tea_stereo_1',
#  '34_tea_cam01',
#  '34_scrambledegg_cam01',
#  '34_friedegg_cam01',
#  '34_sandwich_cam01',
#  '34_juice_cam01',
#  '34_milk_cam01',
#  '34_coffee_cam01',
#  '34_tea_webcam02',
#  '34_sandwich_webcam02',
#  '34_milk_webcam02',
#  '51_coffee_webcam01',
#  '51_scrambledegg_webcam02',
#  '51_tea_webcam02',
#  '36_tea_cam01',
#  '36_milk_webcam01',
#  '36_milk_webcam02',
#  '35_juice_cam01',
#  '35_coffee_cam01',
#  '35_milk_cam01',
#  '35_pancake_cam01',
#  '35_scrambledegg_cam01',
#  '35_friedegg_cam01',
#  '35_juice_webcam02',
#  '35_sandwich_webcam02',
#  '35_salat_webcam02',
#  '35_tea_stereo_1',
#  '35_friedegg_stereo_1',
#  '35_juice_stereo_1',
#  '35_sandwich_stereo_1',
#  '35_cereals_stereo_1',
#  '35_salat_stereo_1',
#  '35_cereals_cam02',
#  '35_coffee_cam02',
#  '42_pancake_webcam02',
#  '42_coffee_stereo_1',
#  '42_scrambledegg_stereo_1',
#  '42_cereals_stereo_1',
#  '33_sandwich_cam01',
#  '33_juice_cam01',
#  '33_cereals_cam01',
#  '33_salat_cam01',
#  '33_cereals_stereo_1',
#  '33_juice_cam02',
#  '33_scrambledegg_cam02',
#  '37_tea_cam01',
#  '37_juice_cam01',
#  '37_coffee_webcam01',
#  '37_coffee_webcam02',
#  '37_coffee_stereo_1',
#  '27_sandwich_cam01',
#  '27_scrambledegg_cam01',
#  '27_friedegg_webcam02',
#  '27_friedegg_stereo_1',
#  '40_milk_cam01',
#  '40_milk_webcam01',
#  '40_pancake_webcam02',
#  '40_salat_webcam02',
#  '40_milk_stereo_1',
#  '40_friedegg_stereo_1',
#  '40_salat_cam02',
#  '40_coffee_cam02',
#  '16_cereals_stereo_1',
#  '7_salat_cam01',
#  '31_pancake_cam01',
#  '31_coffee_stereo_1',
#  '38_coffee_webcam02',
#  '9_tea_cam01',
#  '48_sandwich_webcam01',
#  '48_cereals_webcam02',
#  '48_milk_cam02',
#  '23_coffee_webcam02',
#  '23_scrambledegg_webcam02',
#  '23_juice_stereo_1',
#  '23_sandwich_stereo_1',
#  '23_cereals_stereo_1',
#  '23_juice_cam02',
#  '23_cereals_cam02',
#  '23_sandwich_cam02',
#  '15_scrambledegg_webcam01']

# %%
merged_videos_fvs_common[merged_videos_fvs_common.id.isin(bad_ids)]
# Out:
#                             id  length_x  length_y
# 14           39_salat_webcam02      2669      2666
# 15             39_tea_webcam02      1304      1287
# 24         39_pancake_stereo_1      8990      8984
# 25           39_juice_stereo_1      1811      1808
# 31             39_tea_stereo_1      1304      1290
# ...                        ...       ...       ...
# 1635       23_cereals_stereo_1      1042      1039
# 1637            23_juice_cam02      1711      1708
# 1638          23_cereals_cam02      1042      1039
# 1640         23_sandwich_cam02      1487      1484
# 1659  15_scrambledegg_webcam01      1765      1762
#
# [204 rows x 3 columns]

# %%
fvs_df_cleaner = fvs_df_cleaner[~fvs_df_cleaner.id.isin(bad_ids)]
fvs_df_cleaner
# Out:
#                                                    path  patient   action  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...       18  cereals
# 1     /media/data_cifs2/apra/work/labwork/data/exter...       54  cereals
# 2     /media/data_cifs2/apra/work/labwork/data/exter...       34  cereals
# 3     /media/data_cifs2/apra/work/labwork/data/exter...       13  cereals
# 4     /media/data_cifs2/apra/work/labwork/data/exter...       51  cereals
# ...                                                 ...      ...      ...
# 1707  /media/data_cifs2/apra/work/labwork/data/exter...       36  pancake
# 1708  /media/data_cifs2/apra/work/labwork/data/exter...       54  pancake
# 1709  /media/data_cifs2/apra/work/labwork/data/exter...       13  pancake
# 1710  /media/data_cifs2/apra/work/labwork/data/exter...       21  pancake
# 1711  /media/data_cifs2/apra/work/labwork/data/exter...       12  pancake
#
#         camera  channel                   id  length
# 0     webcam02      NaN  18_cereals_webcam02     461
# 1        cam01      NaN     54_cereals_cam01     743
# 2       stereo      1.0  34_cereals_stereo_1     761
# 3        cam01      NaN     13_cereals_cam01     675
# 4     webcam02      NaN  51_cereals_webcam02     707
# ...        ...      ...                  ...     ...
# 1707  webcam02      NaN  36_pancake_webcam02    7049
# 1708    stereo      1.0  54_pancake_stereo_1    3340
# 1709     cam01      NaN     13_pancake_cam01    4436
# 1710     cam01      NaN     21_pancake_cam01    5841
# 1711  webcam01      NaN  12_pancake_webcam01    2870
#
# [1476 rows x 7 columns]

# %% [markdown]
# ### Adding to the Master DF

# %%
fvs_df_cleaner.rename(columns={'path' : 'path_64dim_fv'}, inplace=True)
fvs_df_cleaner.head()
# Out:
# /media/data/conda/abdullah/envs/bk/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                        path_64dim_fv  patient   action  \
# 0  /media/data_cifs2/apra/work/labwork/data/exter...       18  cereals
# 1  /media/data_cifs2/apra/work/labwork/data/exter...       54  cereals
# 2  /media/data_cifs2/apra/work/labwork/data/exter...       34  cereals
# 3  /media/data_cifs2/apra/work/labwork/data/exter...       13  cereals
# 4  /media/data_cifs2/apra/work/labwork/data/exter...       51  cereals
#
#      camera  channel                   id  length
# 0  webcam02      NaN  18_cereals_webcam02     461
# 1     cam01      NaN     54_cereals_cam01     743
# 2    stereo      1.0  34_cereals_stereo_1     761
# 3     cam01      NaN     13_cereals_cam01     675
# 4  webcam02      NaN  51_cereals_webcam02     707

# %%
master_df = master_df.merge(fvs_df_cleaner[['id', 'path_64dim_fv']], how='outer', on='id')
master_df
# Out:
#                                             path_videos  length  patient  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...    2669       39
# 1     /media/data_cifs2/apra/work/labwork/data/exter...    1304       39
# 2     /media/data_cifs2/apra/work/labwork/data/exter...    8990       39
# 3     /media/data_cifs2/apra/work/labwork/data/exter...     699       39
# 4     /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
# ...                                                 ...     ...      ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...    1123        5
# 1985  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1986  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
#
#         action  camera  channel                 id  \
# 0        salat   cam01      NaN     39_salat_cam01
# 1          tea   cam01      NaN       39_tea_cam01
# 2      pancake   cam01      NaN   39_pancake_cam01
# 3      cereals   cam01      NaN   39_cereals_cam01
# 4     friedegg   cam01      NaN  39_friedegg_cam01
# ...        ...     ...      ...                ...
# 1984    coffee   cam01      NaN     5_coffee_cam01
# 1985     juice  stereo      0.0   5_juice_stereo_0
# 1986      milk  stereo      0.0    5_milk_stereo_0
# 1987     juice  stereo      1.0   5_juice_stereo_1
# 1988      milk  stereo      1.0    5_milk_stereo_1
#
#                                             path_coarse  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
#                                               path_fine  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1984                                                NaN
# 1985                                                NaN
# 1986                                                NaN
# 1987                                                NaN
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
#                                           path_64dim_fv
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
# [1989 rows x 10 columns]

# %% [markdown]
# ## Master vs I3D FVs

# %% [markdown]
# ### 32 Not in Master

# %%
i3d_ids = i3d_df.id.to_list()
master_ids = master_df.id.to_list()
len(i3d_ids)
# Out:
# 1712

# %%
i3d_ids[:5]
# Out:
# ['23_milk_webcam01',
#  '14_tea_webcam01',
#  '18_cereals_webcam02',
#  '49_friedegg_webcam01',
#  '17_tea_webcam02']

# %%
not_in_master = [iid for iid in i3d_ids if iid not in master_ids]
len(not_in_master)
# Out:
# 32

# %%
i3d_df_cleaner = i3d_df[~i3d_df.id.isin(not_in_master)]
i3d_df_cleaner
# Out:
#                                                    path  patient  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...       23
# 1     /media/data_cifs2/apra/work/labwork/data/exter...       14
# 2     /media/data_cifs2/apra/work/labwork/data/exter...       18
# 3     /media/data_cifs2/apra/work/labwork/data/exter...       49
# 4     /media/data_cifs2/apra/work/labwork/data/exter...       17
# ...                                                 ...      ...
# 1707  /media/data_cifs2/apra/work/labwork/data/exter...       30
# 1708  /media/data_cifs2/apra/work/labwork/data/exter...       22
# 1709  /media/data_cifs2/apra/work/labwork/data/exter...       15
# 1710  /media/data_cifs2/apra/work/labwork/data/exter...       25
# 1711  /media/data_cifs2/apra/work/labwork/data/exter...        8
#
#             action    camera  channel                        id  length
# 0             milk  webcam01      NaN          23_milk_webcam01    1246
# 1              tea  webcam01      NaN           14_tea_webcam01     397
# 2          cereals  webcam02      NaN       18_cereals_webcam02     461
# 3         friedegg  webcam01      NaN      49_friedegg_webcam01    5174
# 4              tea  webcam02      NaN           17_tea_webcam02     703
# ...            ...       ...      ...                       ...     ...
# 1707          milk     cam02      NaN             30_milk_cam02     634
# 1708  scrambledegg  webcam02      NaN  22_scrambledegg_webcam02    2291
# 1709        coffee  webcam01      NaN        15_coffee_webcam01     693
# 1710       pancake     cam02      NaN          25_pancake_cam02    5220
# 1711        coffee  webcam01      NaN         8_coffee_webcam01     285
#
# [1680 rows x 7 columns]

# %%
common_videos = master_df[master_df.id.isin(i3d_df_cleaner.id)]
merged_videos_i3d_common = common_videos[['id', 'length']].merge(
    i3d_df_cleaner[['id', 'length']],
    on='id')
merged_videos_i3d_common
# Out:
#                      id  length_x  length_y
# 0        39_salat_cam01      2669      2665
# 1          39_tea_cam01      1304      1300
# 2      39_pancake_cam01      8990      8986
# 3      39_cereals_cam01       699       695
# 4     39_friedegg_cam01      2890      2886
# ...                 ...       ...       ...
# 1675    5_cereals_cam01      1186      1182
# 1676      5_juice_cam01      2795      2791
# 1677     5_coffee_cam01      1123      1119
# 1678   5_juice_stereo_1      2795      2791
# 1679    5_milk_stereo_1      1084      1080
#
# [1680 rows x 3 columns]

# %% [markdown]
# ### Every FV has Different Lengths

# %%
video_lengths = merged_videos_i3d_common.length_x.values
i3d_lengths = merged_videos_i3d_common.length_y.values

# %%
sum(video_lengths != i3d_lengths)
# Out:
# 1680

# %% [markdown]
# ### Majority Are Exactly 4 Frames Less

# %%
sum(video_lengths == i3d_lengths + 4)
# Out:
# 1576

# %% [markdown]
# ### 104 Differ By More than 4 Frames

# %%
sum(video_lengths != i3d_lengths + 4)
# Out:
# 104

# %% [markdown]
# ### Removing the Bad IDs

# %%
bad_ids = merged_videos_i3d_common.iloc[np.where(video_lengths != i3d_lengths+4)].id.to_list()
bad_ids
# Out:
# ['39_salat_webcam02',
#  '39_juice_stereo_1',
#  '41_coffee_cam01',
#  '41_juice_cam01',
#  '41_scrambledegg_webcam01',
#  '41_coffee_webcam01',
#  '41_cereals_webcam01',
#  '41_juice_stereo_1',
#  '41_sandwich_stereo_1',
#  '41_juice_cam02',
#  '50_cereals_webcam01',
#  '50_juice_stereo_1',
#  '4_sandwich_stereo_1',
#  '8_coffee_webcam01',
#  '53_friedegg_webcam01',
#  '53_salat_stereo_1',
#  '53_coffee_cam02',
#  '53_scrambledegg_cam02',
#  '53_pancake_cam02',
#  '43_scrambledegg_cam01',
#  '43_juice_webcam01',
#  '43_juice_stereo_1',
#  '43_juice_cam02',
#  '24_juice_cam01',
#  '24_milk_cam02',
#  '47_coffee_cam01',
#  '47_tea_webcam01',
#  '47_friedegg_webcam01',
#  '47_cereals_webcam02',
#  '47_friedegg_cam02',
#  '26_cereals_cam01',
#  '26_coffee_webcam02',
#  '26_cereals_webcam02',
#  '3_milk_cam01',
#  '3_sandwich_webcam01',
#  '3_cereals_webcam02',
#  '19_salat_cam01',
#  '19_cereals_webcam01',
#  '25_cereals_cam01',
#  '25_friedegg_cam01',
#  '20_juice_webcam02',
#  '20_juice_stereo_1',
#  '13_cereals_webcam01',
#  '13_sandwich_webcam01',
#  '54_pancake_cam01',
#  '54_juice_cam01',
#  '54_salat_cam01',
#  '54_tea_webcam01',
#  '30_juice_cam01',
#  '30_milk_cam02',
#  '32_tea_cam01',
#  '32_milk_cam02',
#  '32_sandwich_cam02',
#  '32_juice_cam02',
#  '49_cereals_cam01',
#  '49_coffee_cam01',
#  '49_milk_webcam01',
#  '49_juice_cam02',
#  '52_cereals_webcam01',
#  '21_sandwich_cam01',
#  '21_cereals_cam02',
#  '45_friedegg_cam02',
#  '18_sandwich_webcam01',
#  '18_milk_webcam01',
#  '18_salat_webcam02',
#  '18_milk_stereo_1',
#  '44_sandwich_cam01',
#  '44_cereals_webcam02',
#  '14_milk_webcam01',
#  '46_friedegg_webcam02',
#  '46_juice_cam02',
#  '17_juice_cam01',
#  '17_cereals_cam01',
#  '51_scrambledegg_webcam02',
#  '51_tea_webcam02',
#  '36_tea_cam01',
#  '36_milk_webcam01',
#  '36_milk_webcam02',
#  '35_coffee_cam01',
#  '35_salat_stereo_1',
#  '42_coffee_stereo_1',
#  '42_scrambledegg_stereo_1',
#  '42_cereals_stereo_1',
#  '27_scrambledegg_cam01',
#  '40_milk_cam01',
#  '40_milk_webcam01',
#  '40_salat_webcam02',
#  '40_milk_stereo_1',
#  '40_friedegg_stereo_1',
#  '40_salat_cam02',
#  '16_cereals_stereo_1',
#  '31_coffee_stereo_1',
#  '9_tea_cam01',
#  '48_sandwich_webcam01',
#  '48_milk_cam02',
#  '23_coffee_webcam02',
#  '23_scrambledegg_webcam02',
#  '23_juice_stereo_1',
#  '23_sandwich_stereo_1',
#  '23_cereals_stereo_1',
#  '23_juice_cam02',
#  '23_cereals_cam02',
#  '23_sandwich_cam02',
#  '15_scrambledegg_webcam01']

# %%
merged_videos_i3d_common[merged_videos_i3d_common.id.isin(bad_ids)]
# Out:
#                             id  length_x  length_y
# 14           39_salat_webcam02      2669      2666
# 25           39_juice_stereo_1      1811      1808
# 45             41_coffee_cam01       876       873
# 46              41_juice_cam01      1582      1579
# 54    41_scrambledegg_webcam01      3022      3019
# ...                        ...       ...       ...
# 1635       23_cereals_stereo_1      1042      1039
# 1637            23_juice_cam02      1711      1708
# 1638          23_cereals_cam02      1042      1039
# 1640         23_sandwich_cam02      1487      1484
# 1659  15_scrambledegg_webcam01      1765      1762
#
# [104 rows x 3 columns]

# %%
i3d_df_cleaner = i3d_df_cleaner[~i3d_df_cleaner.id.isin(bad_ids)]
i3d_df_cleaner
# Out:
#                                                    path  patient  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...       23
# 1     /media/data_cifs2/apra/work/labwork/data/exter...       14
# 2     /media/data_cifs2/apra/work/labwork/data/exter...       18
# 3     /media/data_cifs2/apra/work/labwork/data/exter...       49
# 4     /media/data_cifs2/apra/work/labwork/data/exter...       17
# ...                                                 ...      ...
# 1705  /media/data_cifs2/apra/work/labwork/data/exter...        8
# 1706  /media/data_cifs2/apra/work/labwork/data/exter...       36
# 1708  /media/data_cifs2/apra/work/labwork/data/exter...       22
# 1709  /media/data_cifs2/apra/work/labwork/data/exter...       15
# 1710  /media/data_cifs2/apra/work/labwork/data/exter...       25
#
#             action    camera  channel                        id  length
# 0             milk  webcam01      NaN          23_milk_webcam01    1246
# 1              tea  webcam01      NaN           14_tea_webcam01     397
# 2          cereals  webcam02      NaN       18_cereals_webcam02     461
# 3         friedegg  webcam01      NaN      49_friedegg_webcam01    5174
# 4              tea  webcam02      NaN           17_tea_webcam02     703
# ...            ...       ...      ...                       ...     ...
# 1705         juice  webcam01      NaN          8_juice_webcam01    1248
# 1706         salat  webcam01      NaN         36_salat_webcam01    5292
# 1708  scrambledegg  webcam02      NaN  22_scrambledegg_webcam02    2291
# 1709        coffee  webcam01      NaN        15_coffee_webcam01     693
# 1710       pancake     cam02      NaN          25_pancake_cam02    5220
#
# [1576 rows x 7 columns]

# %% [markdown]
# ### Adding to the Master DF

# %%
i3d_df_cleaner.rename(columns={'path' : 'path_i3d'}, inplace=True)
i3d_df_cleaner.head()
# Out:
# /media/data/conda/abdullah/envs/bk/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                             path_i3d  patient    action  \
# 0  /media/data_cifs2/apra/work/labwork/data/exter...       23      milk
# 1  /media/data_cifs2/apra/work/labwork/data/exter...       14       tea
# 2  /media/data_cifs2/apra/work/labwork/data/exter...       18   cereals
# 3  /media/data_cifs2/apra/work/labwork/data/exter...       49  friedegg
# 4  /media/data_cifs2/apra/work/labwork/data/exter...       17       tea
#
#      camera  channel                    id  length
# 0  webcam01      NaN      23_milk_webcam01    1246
# 1  webcam01      NaN       14_tea_webcam01     397
# 2  webcam02      NaN   18_cereals_webcam02     461
# 3  webcam01      NaN  49_friedegg_webcam01    5174
# 4  webcam02      NaN       17_tea_webcam02     703

# %%
master_df = master_df.merge(i3d_df_cleaner[['id', 'path_i3d']], how='outer', on='id')
master_df
# Out:
#                                             path_videos  length  patient  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...    2669       39
# 1     /media/data_cifs2/apra/work/labwork/data/exter...    1304       39
# 2     /media/data_cifs2/apra/work/labwork/data/exter...    8990       39
# 3     /media/data_cifs2/apra/work/labwork/data/exter...     699       39
# 4     /media/data_cifs2/apra/work/labwork/data/exter...    2890       39
# ...                                                 ...     ...      ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...    1123        5
# 1985  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1986  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...    2795        5
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...    1084        5
#
#         action  camera  channel                 id  \
# 0        salat   cam01      NaN     39_salat_cam01
# 1          tea   cam01      NaN       39_tea_cam01
# 2      pancake   cam01      NaN   39_pancake_cam01
# 3      cereals   cam01      NaN   39_cereals_cam01
# 4     friedegg   cam01      NaN  39_friedegg_cam01
# ...        ...     ...      ...                ...
# 1984    coffee   cam01      NaN     5_coffee_cam01
# 1985     juice  stereo      0.0   5_juice_stereo_0
# 1986      milk  stereo      0.0    5_milk_stereo_0
# 1987     juice  stereo      1.0   5_juice_stereo_1
# 1988      milk  stereo      1.0    5_milk_stereo_1
#
#                                             path_coarse  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
#                                               path_fine  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1984                                                NaN
# 1985                                                NaN
# 1986                                                NaN
# 1987                                                NaN
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
#                                           path_64dim_fv  \
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
#                                                path_i3d
# 0     /media/data_cifs2/apra/work/labwork/data/exter...
# 1     /media/data_cifs2/apra/work/labwork/data/exter...
# 2     /media/data_cifs2/apra/work/labwork/data/exter...
# 3     /media/data_cifs2/apra/work/labwork/data/exter...
# 4     /media/data_cifs2/apra/work/labwork/data/exter...
# ...                                                 ...
# 1984  /media/data_cifs2/apra/work/labwork/data/exter...
# 1985                                                NaN
# 1986                                                NaN
# 1987  /media/data_cifs2/apra/work/labwork/data/exter...
# 1988  /media/data_cifs2/apra/work/labwork/data/exter...
#
# [1989 rows x 11 columns]

# %% [markdown]
# ## Saving Master DF

# %%
master_df.to_csv(str(DIR_RAW_BREAKFAST / 'master_meta.csv'), index=False)
